# %% [markdown]
# ## Logical Operators
# 1. And
# 2. or
# 3. not

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False

# %%
not int(bool(0))
# Out:
# True

# %%
not int(bool(1))
# Out:
# False

# %% [markdown]
# ## Logical And

# %%
not 1
# Out:
# False

# %%
not True * True
# Out:
# False

# %%
False * True
# Out:
# 0

# %%
not False * True
# Out:
# True

# %%
not False * True == True
# Out:
# True

# %%
not False * True != True
# Out:
# False

# %%
not False * True != False
# Out:
# True

# %%
lst_a=[1,2,3,4]
lst_b=[1,2,3,4]

# %%
print(id(lst_a))
# Out:
# 4419916928

# %%
id(lst_b)
# Out:
# 4419918336

# %%
# string is immutable
# in list elements are mutable

# %%
## comparision operation

# %% [markdown]
# ## Arithimetic Operations

# %%
a=25
b=101

# %%
b+a
# Out:
# 126

# %% [markdown]
# a/b

# %%
b/a
# Out:
# 4.04

# %%
b//a
# Out:
# 4

# %%
b%a
# Out:
# 1

# %%
# % is modulus, displaying the reminder
a%b
# Out:
# 25

# %% [markdown]
# ## Bitwise Operators

# %%
var=10
bin(var)
# Out:
# '0b1010'

# %%
bin(int(10))
# Out:
# '0b1010'

# %%
var >> 1
# Out:
# 5

# %%
var << 1
# Out:
# 20

# %%
~var
# Out:
# -11

# %%
~15
# Out:
# -16

# %% [markdown]
# ## Strings

# %%
## we define by '' or " "
"Welcome to DS"
'Welcome to DS'
# Out:
# 'Welcome to DS'

# %%
str1="Rithvik"

# %%
str1.index
# Out:
# <function str.index>

# %%
name="Karthik"
name[-5:2]
# Out:
# ''

# %%
name[1::-1]
# Out:
# 'aK'

# %%
course_name="Data Science Masters"

# %%
course_name[5:12]
# Out:
# 'Science'

# %%
course_name[11:4:-1]
# Out:
# 'ecneicS'

# %%
## Concatination

# %%
len(course_name)
# Out:
# 20

# %%
## find function
course_name.find('D')
# Out:
# 0

# %%
course_name.find('t',0,4)
# Out:
# 2

# %%
course_name.partition(" ")
# Out:
# ('Data', ' ', 'Science Masters')

# %%
course_name.swapcase()
# Out:
# 'dATA sCIENCE mASTERS'

# %%
# we use functions in web scrapping

# %%
course_name.split()
# Out:
# ['Data', 'Science', 'Masters']
