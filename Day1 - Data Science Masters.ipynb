# %% [markdown]
# First Day1

# %%
1+1
# Out:
# 2

# %%
## is used for comments
## this is a function
# this is a comment
a = 20
a
# Out:
# 20

# %%
"""
hello this is an example of multi line comments
x
y
z
..
"""
a = 20
a
# Out:
# 20

# %% [markdown]
# # hello
# ## hello 1
# ### hello 2
# 1. hello this is numbering

# %% [markdown]
# ## Numbers

# %%
1+3
# Out:
# 4

# %%
print(1+3)
# Out:
# 4

# %%
a=5
print(a)
# Out:
# 5

# %%
print("Hello World my name is Rithvik \nI am learning data science this is day1")
# Out:
# Hello World my name is Rithvik
# I am learning data science this is day1

# %% [markdown]
# # Variable Assignmenets

# %%
name="Rithvik"
job="student"

# %%
name="Bala"

# %%
job
# Out:
# 'student'

# %%
number=10

# %%
number
# Out:
# 10

# %%
name ## here name is overridden
# Out:
# 'Bala'

# %%
type(name)
# Out:
# str

# %%
type(number)
# Out:
# int

# %%
## float
decimal_num=2.5

# %%
decimal_num
# Out:
# 2.5

# %%
type(decimal_num)
# Out:
# float

# %%
1+2j
# Out:
# (1+2j)

# %%
type(1+2j)
# Out:
# complex

# %%
type("")
# Out:
# str

# %%
type('')
# Out:
# str

# %%
## bad way to write, never use a number before a variable
1a
3number
# Out:
#   Cell In[53], line 2
#     1a
#     ^
# SyntaxError: invalid decimal literal

# %%
number1=22

# %%
## Variables are case sensitive
company='ineuron'
Company='pwskills'
print(company)
print(Company)
# Out:
# ineuron
# pwskills

# %%
## Reserved Keywords (you cant mess with their values)
''' 
int, float, len,complex, bool,str,retutn,yield
'''
# Out:
# ' \nint, float, len,complex, bool,str,retutn,yield\n'

# %%
## Boolean
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
type(not False)
# Out:
# bool

# %%
## Typecasting (Converting a number into boolean value)
bool(0)
# Out:
# False

# %%
## can you convert a number into a string
str(23)
# Out:
# '23'

# %%
int('23')
# Out:
# 23

# %%
type(int('23'))
# Out:
# int

# %%
bool(1)
# Out:
# True

# %% [markdown]
# ### Dynamic Typing

# %%
int(1.54)
# Out:
# 1

# %%
type(int(1.54))
# Out:
# int

# %%
## concatenation between different types

# %%
## this will give error
int("1") + "1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 int("1") + "1"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
"1" * "1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 "1" * "1"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"1" * 100
# Out:
# '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111'

# %%
"1" * int("1")
# Out:
# '1'

# %%
bool(-1)
# Out:
# True

# %%
type("1" * int("1"))
# Out:
# str

# %%
type(bool(-1))
# Out:
# bool
